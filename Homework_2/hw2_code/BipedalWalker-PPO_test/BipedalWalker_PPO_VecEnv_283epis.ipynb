# %% [markdown]
# # BipedalWalker-v2 with PPO, Vectorized Environment
# In this notebook, you will implement a PPO agent with OpenAI Gym's BipedalWalker-v2 environment.
#
# ### 1. Create Vectorized Environment

# %%
import gym
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt

from  collections  import deque
import time
from model import Policy
from ppo import ppo_agent
from storage import RolloutStorage
from utils import get_render_func, get_vec_normalize
from envs import make_vec_envs
from parallelEnv import parallelEnv
import matplotlib.pyplot as plt
# %matplotlib inline

print('gym version: ', gym.__version__)
print('torch version: ', torch.__version__)

seed = 0 
gamma=0.99
num_processes=16 
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device: ', device)

envs = parallelEnv('BipedalWalker-v2', n=num_processes, seed=seed)

## make_vec_envs -cannot find context for 'forkserver'
## forkserver is only available in Python 3.4+ and only on some Unix platforms (not on Windows).
## envs = make_vec_envs('BipedalWalker-v2', \
##                    seed + 1000, num_processes,
##                    None, None, False, device='cpu', allow_early_resets=False)

max_steps = envs.max_steps
print('max_steps: ', max_steps)

torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
# Out:
# gym version:  0.10.9
# torch version:  1.9.0+cu111
# device:  cuda:0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# d:\Python\Python37\lib\site-packages\gym\envs\registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# max_steps:  1600

# %% [markdown]
# ### 2. Instantiate Model, Agent and Storage
#
# Initialize the Policy (model MLPBase), PPO Agent and Rollout Storage.

# %%
## model Policy uses MLPBase
policy = Policy(envs.observation_space.shape, envs.action_space,\
        base_kwargs={'recurrent': False})

policy.to(device)

agent = ppo_agent(actor_critic=policy, ppo_epoch=16, num_mini_batch=16,\
                lr=0.001, eps=1e-5, max_grad_norm=0.5)

rollouts = RolloutStorage(num_steps=max_steps, num_processes=num_processes, \
                        obs_shape=envs.observation_space.shape, action_space=envs.action_space, \
                        recurrent_hidden_state_size=policy.recurrent_hidden_state_size)

obs = envs.reset()
print('type obs: ', type(obs), ', shape obs: ', obs.shape)
obs_t = torch.tensor(obs)
print('type obs_t: ', type(obs_t), ', shape obs_t: ', obs_t.shape)

rollouts.obs[0].copy_(obs_t)
rollouts.to(device)
# Out:
# type obs:  <class 'numpy.ndarray'> , shape obs:  (16, 24)
# type obs_t:  <class 'torch.Tensor'> , shape obs_t:  torch.Size([16, 24])

# %% [markdown]
# ### 3.Save model function

# %%
def save(model, directory, filename, suffix):
    torch.save(model.base.actor.state_dict(), '%s/%s_actor_%s.pth' % (directory, filename, suffix))
    torch.save(model.base.critic.state_dict(), '%s/%s_critic_%s.pth' % (directory, filename, suffix))
    torch.save(model.base.critic_linear.state_dict(), '%s/%s_critic_linear_%s.pth' % (directory, filename, suffix))
    
limits = [-300, -160, -100, -70, -50, 0, 20, 30, 40, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330]

def return_suffix(j):
    suf = '0'
    for i in range(len(limits)-1):
        if j > limits[i] and j < limits[i+1]:
            suf = str(limits[i+1])
            break
        
        i_last = len(limits)-1    
        if  j > limits[i_last]:
            suf = str(limits[i_last])
            break
    return suf

# %% [markdown]
# ### 4. Train the Agent  with Vectorized Environment

# %%
num_updates=1000000
gamma = 0.99
tau=0.95
save_interval=30
log_interval= 1 

def ppo_vec_env_train(envs, agent, policy, num_processes, num_steps, rollouts):
    
    time_start = time.time()
    
    n=len(envs.ps)    
    envs.reset()
    
    # start all parallel agents
    print('Number of agents: ', n)
    envs.step([[1]*4]*n)
    
    indices = []
    for i  in range(n):
        indices.append(i)
     
    s = 0
    
    scores_deque = deque(maxlen=100)
    scores_array = []
    avg_scores_array = []    

    for i_episode in range(num_updates):
        
        total_reward = np.zeros(n)
        timestep = 0
        
        for timestep in range(num_steps):

            with torch.no_grad():
                value, actions, action_log_prob, recurrent_hidden_states = \
                   policy.act(
                        rollouts.obs[timestep],
                        rollouts.recurrent_hidden_states[timestep],
                        rollouts.masks[timestep])
                
            obs, rewards, done, infos = envs.step(actions.cpu().detach().numpy())
            
            total_reward += rewards  ## this is the list by agents
                        
            # If done then clean the history of observations.
            masks = torch.FloatTensor([[0.0] if done_ else [1.0] for done_ in done])
            obs_t = torch.tensor(obs)
            ## Add one dimnesion to tensor, otherwise does not work
            ## This is (unsqueeze(1)) solution for:
            ## RuntimeError: The expanded size of the tensor (1) must match the existing size...
            rewards_t = torch.tensor(rewards).unsqueeze(1)
            rollouts.insert(obs_t, recurrent_hidden_states, actions, action_log_prob, \
                value, rewards_t, masks)
                    
        avg_total_reward = np.mean(total_reward)
        scores_deque.append(avg_total_reward)
        scores_array.append(avg_total_reward)
                
        with torch.no_grad():
            next_value = policy.get_value(rollouts.obs[-1],
                            rollouts.recurrent_hidden_states[-1],
                            rollouts.masks[-1]).detach()

        rollouts.compute_returns(next_value, gamma, tau)

        agent.update(rollouts)

        rollouts.after_update()
        
        avg_score = np.mean(scores_deque)
        avg_scores_array.append(avg_score)

        if i_episode > 0 and i_episode % save_interval == 0:
            print('Saving model, i_episode: ', i_episode, '\n')
            suf = return_suffix(avg_score)
            save(policy, 'dir_save', 'we0', suf)
            #save_venv(policy, 'dir_save_VecEnv', 'final')

        
        if i_episode % log_interval == 0 and len(scores_deque) > 1:            
            prev_s = s
            s = (int)(time.time() - time_start)
            t_del = s - prev_s
            print('Ep. {}, Timesteps {}, Score.Agents: {:.2f}, Avg.Score: {:.2f}, Time: {:02}:{:02}:{:02}, \
Interval: {:02}:{:02}'\
                   .format(i_episode, timestep+1, \
                        avg_total_reward, avg_score, s//3600, s%3600//60, s%60, t_del%3600//60, t_del%60)) 
    
        if len(scores_deque) == 100 and np.mean(scores_deque) > 250.0:   
        # if np.mean(scores_deque) > 20:   
            print('Environment solved with Average Score: ',  np.mean(scores_deque) )
            break
    
    
    return scores_array, avg_scores_array

# %%
scores, avg_scores = ppo_vec_env_train(envs, agent, policy, num_processes, max_steps, rollouts)
# Out:
# Number of agents:  16
# Ep. 1, Timesteps 1600, Score.Agents: -607.38, Avg.Score: -833.94, Time: 00:00:20, Interval: 00:20
# Ep. 2, Timesteps 1600, Score.Agents: -607.61, Avg.Score: -758.50, Time: 00:00:29, Interval: 00:09
# Ep. 3, Timesteps 1600, Score.Agents: -427.87, Avg.Score: -675.84, Time: 00:00:38, Interval: 00:09
# Ep. 4, Timesteps 1600, Score.Agents: -397.39, Avg.Score: -620.15, Time: 00:00:47, Interval: 00:09
# Ep. 5, Timesteps 1600, Score.Agents: -305.20, Avg.Score: -567.66, Time: 00:00:57, Interval: 00:10
# Ep. 6, Timesteps 1600, Score.Agents: -296.80, Avg.Score: -528.96, Time: 00:01:06, Interval: 00:09
# Ep. 7, Timesteps 1600, Score.Agents: -296.48, Avg.Score: -499.90, Time: 00:01:15, Interval: 00:09
# Ep. 8, Timesteps 1600, Score.Agents: -173.88, Avg.Score: -463.68, Time: 00:01:24, Interval: 00:09
# Ep. 9, Timesteps 1600, Score.Agents: -187.23, Avg.Score: -436.03, Time: 00:01:33, Interval: 00:09
# Ep. 10, Timesteps 1600, Score.Agents: -204.04, Avg.Score: -414.94, Time: 00:01:42, Interval: 00:09
# Ep. 11, Timesteps 1600, Score.Agents: -192.05, Avg.Score: -396.37, Time: 00:01:51, Interval: 00:09
# Ep. 12, Timesteps 1600, Score.Agents: -168.21, Avg.Score: -378.82, Time: 00:02:00, Interval: 00:09
# Ep. 13, Timesteps 1600, Score.Agents: -145.26, Avg.Score: -362.14, Time: 00:02:08, Interval: 00:08
# Ep. 14, Timesteps 1600, Score.Agents: -163.52, Avg.Score: -348.89, Time: 00:02:17, Interval: 00:09
# Ep. 15, Timesteps 1600, Score.Agents: -148.80, Avg.Score: -336.39, Time: 00:02:26, Interval: 00:09
# Ep. 16, Timesteps 1600, Score.Agents: -106.83, Avg.Score: -322.89, Time: 00:02:35, Interval: 00:09
# Ep. 17, Timesteps 1600, Score.Agents: -112.18, Avg.Score: -311.18, Time: 00:02:43, Interval: 00:08
# Ep. 18, Timesteps 1600, Score.Agents: -95.98, Avg.Score: -299.85, Time: 00:02:52, Interval: 00:09
# Ep. 19, Timesteps 1600, Score.Agents: -107.14, Avg.Score: -290.22, Time: 00:03:01, Interval: 00:09
# Ep. 20, Timesteps 1600, Score.Agents: -111.87, Avg.Score: -281.73, Time: 00:03:10, Interval: 00:09
# Ep. 21, Timesteps 1600, Score.Agents: -96.33, Avg.Score: -273.30, Time: 00:03:19, Interval: 00:09
# Ep. 22, Timesteps 1600, Score.Agents: -87.53, Avg.Score: -265.22, Time: 00:03:28, Interval: 00:09
# Ep. 23, Timesteps 1600, Score.Agents: -74.76, Avg.Score: -257.29, Time: 00:03:37, Interval: 00:09
# Ep. 24, Timesteps 1600, Score.Agents: -89.28, Avg.Score: -250.57, Time: 00:03:47, Interval: 00:10
# Ep. 25, Timesteps 1600, Score.Agents: -100.16, Avg.Score: -244.78, Time: 00:03:54, Interval: 00:07
# Ep. 26, Timesteps 1600, Score.Agents: -68.34, Avg.Score: -238.25, Time: 00:04:03, Interval: 00:09
# Ep. 27, Timesteps 1600, Score.Agents: -85.38, Avg.Score: -232.79, Time: 00:04:12, Interval: 00:09
# Ep. 28, Timesteps 1600, Score.Agents: -84.63, Avg.Score: -227.68, Time: 00:04:20, Interval: 00:08
# Ep. 29, Timesteps 1600, Score.Agents: -88.83, Avg.Score: -223.05, Time: 00:04:28, Interval: 00:08
# Saving model, i_episode:  30
#
# Ep. 30, Timesteps 1600, Score.Agents: -110.05, Avg.Score: -219.40, Time: 00:04:35, Interval: 00:07
# Ep. 31, Timesteps 1600, Score.Agents: -72.15, Avg.Score: -214.80, Time: 00:04:42, Interval: 00:07
# Ep. 32, Timesteps 1600, Score.Agents: -83.90, Avg.Score: -210.84, Time: 00:04:49, Interval: 00:07
# Ep. 33, Timesteps 1600, Score.Agents: -52.04, Avg.Score: -206.16, Time: 00:04:56, Interval: 00:07
# Ep. 34, Timesteps 1600, Score.Agents: -48.15, Avg.Score: -201.65, Time: 00:05:03, Interval: 00:07
# Ep. 35, Timesteps 1600, Score.Agents: -87.81, Avg.Score: -198.49, Time: 00:05:10, Interval: 00:07
# Ep. 36, Timesteps 1600, Score.Agents: -79.13, Avg.Score: -195.26, Time: 00:05:17, Interval: 00:07
# Ep. 37, Timesteps 1600, Score.Agents: -99.03, Avg.Score: -192.73, Time: 00:05:23, Interval: 00:06
# Ep. 38, Timesteps 1600, Score.Agents: -103.50, Avg.Score: -190.44, Time: 00:05:30, Interval: 00:07
# Ep. 39, Timesteps 1600, Score.Agents: -58.00, Avg.Score: -187.13, Time: 00:05:37, Interval: 00:07
# Ep. 40, Timesteps 1600, Score.Agents: -34.12, Avg.Score: -183.40, Time: 00:05:44, Interval: 00:07
# Ep. 41, Timesteps 1600, Score.Agents: -45.21, Avg.Score: -180.11, Time: 00:05:51, Interval: 00:07
# Ep. 42, Timesteps 1600, Score.Agents: -64.63, Avg.Score: -177.42, Time: 00:05:58, Interval: 00:07
# Ep. 43, Timesteps 1600, Score.Agents: -34.89, Avg.Score: -174.18, Time: 00:06:04, Interval: 00:06
# Ep. 44, Timesteps 1600, Score.Agents: -18.88, Avg.Score: -170.73, Time: 00:06:11, Interval: 00:07
# Ep. 45, Timesteps 1600, Score.Agents: -64.53, Avg.Score: -168.42, Time: 00:06:18, Interval: 00:07
# Ep. 46, Timesteps 1600, Score.Agents: -38.09, Avg.Score: -165.65, Time: 00:06:25, Interval: 00:07
# Ep. 47, Timesteps 1600, Score.Agents: -11.44, Avg.Score: -162.44, Time: 00:06:32, Interval: 00:07
# Ep. 48, Timesteps 1600, Score.Agents: -2.47, Avg.Score: -159.17, Time: 00:06:39, Interval: 00:07
# Ep. 49, Timesteps 1600, Score.Agents: -30.43, Avg.Score: -156.60, Time: 00:06:45, Interval: 00:06
# Ep. 50, Timesteps 1600, Score.Agents: -37.60, Avg.Score: -154.27, Time: 00:06:52, Interval: 00:07
# Ep. 51, Timesteps 1600, Score.Agents: -13.80, Avg.Score: -151.56, Time: 00:06:59, Interval: 00:07
# Ep. 52, Timesteps 1600, Score.Agents: -24.44, Avg.Score: -149.17, Time: 00:07:06, Interval: 00:07
# Ep. 53, Timesteps 1600, Score.Agents: 4.58, Avg.Score: -146.32, Time: 00:07:13, Interval: 00:07
# Ep. 54, Timesteps 1600, Score.Agents: 8.77, Avg.Score: -143.50, Time: 00:07:19, Interval: 00:06
# Ep. 55, Timesteps 1600, Score.Agents: 17.99, Avg.Score: -140.61, Time: 00:07:26, Interval: 00:07
# Ep. 56, Timesteps 1600, Score.Agents: 15.85, Avg.Score: -137.87, Time: 00:07:33, Interval: 00:07
# Ep. 57, Timesteps 1600, Score.Agents: 28.79, Avg.Score: -135.00, Time: 00:07:40, Interval: 00:07
# Ep. 58, Timesteps 1600, Score.Agents: 15.32, Avg.Score: -132.45, Time: 00:07:46, Interval: 00:06
# Ep. 59, Timesteps 1600, Score.Agents: 44.26, Avg.Score: -129.50, Time: 00:07:53, Interval: 00:07
# Saving model, i_episode:  60
#
# Ep. 60, Timesteps 1600, Score.Agents: 45.52, Avg.Score: -126.63, Time: 00:08:00, Interval: 00:07
# Ep. 61, Timesteps 1600, Score.Agents: 37.82, Avg.Score: -123.98, Time: 00:08:07, Interval: 00:07
# Ep. 62, Timesteps 1600, Score.Agents: 31.48, Avg.Score: -121.51, Time: 00:08:13, Interval: 00:06
# Ep. 63, Timesteps 1600, Score.Agents: 43.79, Avg.Score: -118.93, Time: 00:08:20, Interval: 00:07
# Ep. 64, Timesteps 1600, Score.Agents: 30.59, Avg.Score: -116.63, Time: 00:08:27, Interval: 00:07
# Ep. 65, Timesteps 1600, Score.Agents: 33.47, Avg.Score: -114.36, Time: 00:08:34, Interval: 00:07
# Ep. 66, Timesteps 1600, Score.Agents: 51.71, Avg.Score: -111.88, Time: 00:08:41, Interval: 00:07
# Ep. 67, Timesteps 1600, Score.Agents: 33.56, Avg.Score: -109.74, Time: 00:08:48, Interval: 00:07
# Ep. 68, Timesteps 1600, Score.Agents: 24.06, Avg.Score: -107.80, Time: 00:08:55, Interval: 00:07
# Ep. 69, Timesteps 1600, Score.Agents: 44.91, Avg.Score: -105.62, Time: 00:09:02, Interval: 00:07
# Ep. 70, Timesteps 1600, Score.Agents: 42.88, Avg.Score: -103.53, Time: 00:09:08, Interval: 00:06
# Ep. 71, Timesteps 1600, Score.Agents: 53.50, Avg.Score: -101.35, Time: 00:09:15, Interval: 00:07
# Ep. 72, Timesteps 1600, Score.Agents: 28.20, Avg.Score: -99.57, Time: 00:09:22, Interval: 00:07
# Ep. 73, Timesteps 1600, Score.Agents: 73.70, Avg.Score: -97.23, Time: 00:09:29, Interval: 00:07
# Ep. 74, Timesteps 1600, Score.Agents: 57.20, Avg.Score: -95.17, Time: 00:09:36, Interval: 00:07
# Ep. 75, Timesteps 1600, Score.Agents: 54.89, Avg.Score: -93.20, Time: 00:09:42, Interval: 00:06
# Ep. 76, Timesteps 1600, Score.Agents: 49.56, Avg.Score: -91.34, Time: 00:09:49, Interval: 00:07
# Ep. 77, Timesteps 1600, Score.Agents: 62.10, Avg.Score: -89.38, Time: 00:09:56, Interval: 00:07
# Ep. 78, Timesteps 1600, Score.Agents: 60.59, Avg.Score: -87.48, Time: 00:10:03, Interval: 00:07
# Ep. 79, Timesteps 1600, Score.Agents: 82.50, Avg.Score: -85.35, Time: 00:10:10, Interval: 00:07
# Ep. 80, Timesteps 1600, Score.Agents: 77.07, Avg.Score: -83.35, Time: 00:10:17, Interval: 00:07
# Ep. 81, Timesteps 1600, Score.Agents: 83.01, Avg.Score: -81.32, Time: 00:10:23, Interval: 00:06
# Ep. 82, Timesteps 1600, Score.Agents: 80.98, Avg.Score: -79.36, Time: 00:10:30, Interval: 00:07
# Ep. 83, Timesteps 1600, Score.Agents: 91.90, Avg.Score: -77.32, Time: 00:10:37, Interval: 00:07
# Ep. 84, Timesteps 1600, Score.Agents: 76.90, Avg.Score: -75.51, Time: 00:10:44, Interval: 00:07
# Ep. 85, Timesteps 1600, Score.Agents: 94.75, Avg.Score: -73.53, Time: 00:10:51, Interval: 00:07
# Ep. 86, Timesteps 1600, Score.Agents: 98.05, Avg.Score: -71.56, Time: 00:10:58, Interval: 00:07
# Ep. 87, Timesteps 1600, Score.Agents: 94.16, Avg.Score: -69.67, Time: 00:11:05, Interval: 00:07
# Ep. 88, Timesteps 1600, Score.Agents: 82.70, Avg.Score: -67.96, Time: 00:11:12, Interval: 00:07
# Ep. 89, Timesteps 1600, Score.Agents: 93.10, Avg.Score: -66.17, Time: 00:11:19, Interval: 00:07
# Saving model, i_episode:  90
#
# Ep. 90, Timesteps 1600, Score.Agents: 103.17, Avg.Score: -64.31, Time: 00:11:25, Interval: 00:06
# Ep. 91, Timesteps 1600, Score.Agents: 99.12, Avg.Score: -62.54, Time: 00:11:32, Interval: 00:07
# Ep. 92, Timesteps 1600, Score.Agents: 85.88, Avg.Score: -60.94, Time: 00:11:39, Interval: 00:07
# Ep. 93, Timesteps 1600, Score.Agents: 95.09, Avg.Score: -59.28, Time: 00:11:46, Interval: 00:07
# Ep. 94, Timesteps 1600, Score.Agents: 109.49, Avg.Score: -57.50, Time: 00:11:52, Interval: 00:06
# Ep. 95, Timesteps 1600, Score.Agents: 101.40, Avg.Score: -55.85, Time: 00:11:59, Interval: 00:07
# Ep. 96, Timesteps 1600, Score.Agents: 72.18, Avg.Score: -54.53, Time: 00:12:06, Interval: 00:07
# Ep. 97, Timesteps 1600, Score.Agents: 106.61, Avg.Score: -52.88, Time: 00:12:13, Interval: 00:07
# Ep. 98, Timesteps 1600, Score.Agents: 110.16, Avg.Score: -51.24, Time: 00:12:20, Interval: 00:07
# Ep. 99, Timesteps 1600, Score.Agents: 96.71, Avg.Score: -49.76, Time: 00:12:26, Interval: 00:06
# Ep. 100, Timesteps 1600, Score.Agents: 87.12, Avg.Score: -38.28, Time: 00:12:33, Interval: 00:07
# Ep. 101, Timesteps 1600, Score.Agents: 106.76, Avg.Score: -31.14, Time: 00:12:40, Interval: 00:07
# Ep. 102, Timesteps 1600, Score.Agents: 122.29, Avg.Score: -23.84, Time: 00:12:47, Interval: 00:07
# Ep. 103, Timesteps 1600, Score.Agents: 121.05, Avg.Score: -18.35, Time: 00:12:54, Interval: 00:07
# Ep. 104, Timesteps 1600, Score.Agents: 113.88, Avg.Score: -13.24, Time: 00:13:00, Interval: 00:06
# Ep. 105, Timesteps 1600, Score.Agents: 120.77, Avg.Score: -8.98, Time: 00:13:07, Interval: 00:07
# Ep. 106, Timesteps 1600, Score.Agents: 117.26, Avg.Score: -4.84, Time: 00:13:14, Interval: 00:07
# Ep. 107, Timesteps 1600, Score.Agents: 115.49, Avg.Score: -0.72, Time: 00:13:21, Interval: 00:07
# Ep. 108, Timesteps 1600, Score.Agents: 97.66, Avg.Score: 2.00, Time: 00:13:28, Interval: 00:07
# Ep. 109, Timesteps 1600, Score.Agents: 118.79, Avg.Score: 5.06, Time: 00:13:34, Interval: 00:06
# Ep. 110, Timesteps 1600, Score.Agents: 117.96, Avg.Score: 8.28, Time: 00:13:41, Interval: 00:07
# Ep. 111, Timesteps 1600, Score.Agents: 126.05, Avg.Score: 11.46, Time: 00:13:48, Interval: 00:07
# Ep. 112, Timesteps 1600, Score.Agents: 142.24, Avg.Score: 14.56, Time: 00:13:55, Interval: 00:07
# Ep. 113, Timesteps 1600, Score.Agents: 129.99, Avg.Score: 17.31, Time: 00:14:02, Interval: 00:07
# Ep. 114, Timesteps 1600, Score.Agents: 127.97, Avg.Score: 20.23, Time: 00:14:08, Interval: 00:06
# Ep. 115, Timesteps 1600, Score.Agents: 136.08, Avg.Score: 23.08, Time: 00:14:15, Interval: 00:07
# Ep. 116, Timesteps 1600, Score.Agents: 110.34, Avg.Score: 25.25, Time: 00:14:22, Interval: 00:07
# Ep. 117, Timesteps 1600, Score.Agents: 132.69, Avg.Score: 27.70, Time: 00:14:29, Interval: 00:07
# Ep. 118, Timesteps 1600, Score.Agents: 95.76, Avg.Score: 29.62, Time: 00:14:35, Interval: 00:06
# Ep. 119, Timesteps 1600, Score.Agents: 126.67, Avg.Score: 31.95, Time: 00:14:42, Interval: 00:07
# Saving model, i_episode:  120
#
# Ep. 120, Timesteps 1600, Score.Agents: 110.87, Avg.Score: 34.18, Time: 00:14:49, Interval: 00:07
# Ep. 121, Timesteps 1600, Score.Agents: 118.11, Avg.Score: 36.33, Time: 00:14:57, Interval: 00:08
# Ep. 122, Timesteps 1600, Score.Agents: 126.39, Avg.Score: 38.47, Time: 00:15:09, Interval: 00:12
# Ep. 123, Timesteps 1600, Score.Agents: 127.87, Avg.Score: 40.49, Time: 00:15:20, Interval: 00:11
# Ep. 124, Timesteps 1600, Score.Agents: 145.32, Avg.Score: 42.84, Time: 00:15:32, Interval: 00:12
# Ep. 125, Timesteps 1600, Score.Agents: 133.89, Avg.Score: 45.18, Time: 00:15:43, Interval: 00:11
# Ep. 126, Timesteps 1600, Score.Agents: 119.10, Avg.Score: 47.05, Time: 00:15:54, Interval: 00:11
# Ep. 127, Timesteps 1600, Score.Agents: 145.12, Avg.Score: 49.36, Time: 00:16:05, Interval: 00:11
# Ep. 128, Timesteps 1600, Score.Agents: 155.89, Avg.Score: 51.76, Time: 00:16:14, Interval: 00:09
# Ep. 129, Timesteps 1600, Score.Agents: 141.35, Avg.Score: 54.06, Time: 00:16:22, Interval: 00:08
# Ep. 130, Timesteps 1600, Score.Agents: 155.57, Avg.Score: 56.72, Time: 00:16:29, Interval: 00:07
# Ep. 131, Timesteps 1600, Score.Agents: 143.29, Avg.Score: 58.88, Time: 00:16:37, Interval: 00:08
# Ep. 132, Timesteps 1600, Score.Agents: 151.54, Avg.Score: 61.23, Time: 00:16:44, Interval: 00:07
# Ep. 133, Timesteps 1600, Score.Agents: 136.83, Avg.Score: 63.12, Time: 00:16:52, Interval: 00:08
# Ep. 134, Timesteps 1600, Score.Agents: 143.64, Avg.Score: 65.04, Time: 00:17:00, Interval: 00:08
# Ep. 135, Timesteps 1600, Score.Agents: 153.54, Avg.Score: 67.45, Time: 00:17:08, Interval: 00:08
# Ep. 136, Timesteps 1600, Score.Agents: 155.95, Avg.Score: 69.80, Time: 00:17:16, Interval: 00:08
# Ep. 137, Timesteps 1600, Score.Agents: 143.43, Avg.Score: 72.23, Time: 00:17:24, Interval: 00:08
# Ep. 138, Timesteps 1600, Score.Agents: 144.00, Avg.Score: 74.70, Time: 00:17:32, Interval: 00:08
# Ep. 139, Timesteps 1600, Score.Agents: 148.46, Avg.Score: 76.76, Time: 00:17:40, Interval: 00:08
# Ep. 140, Timesteps 1600, Score.Agents: 160.06, Avg.Score: 78.71, Time: 00:17:48, Interval: 00:08
# Ep. 141, Timesteps 1600, Score.Agents: 108.18, Avg.Score: 80.24, Time: 00:17:57, Interval: 00:09
# Ep. 142, Timesteps 1600, Score.Agents: 130.88, Avg.Score: 82.20, Time: 00:18:06, Interval: 00:09
# Ep. 143, Timesteps 1600, Score.Agents: 144.78, Avg.Score: 83.99, Time: 00:18:16, Interval: 00:10
# Ep. 144, Timesteps 1600, Score.Agents: 140.68, Avg.Score: 85.59, Time: 00:18:24, Interval: 00:08
# Ep. 145, Timesteps 1600, Score.Agents: 119.39, Avg.Score: 87.43, Time: 00:18:32, Interval: 00:08
# Ep. 146, Timesteps 1600, Score.Agents: 132.94, Avg.Score: 89.14, Time: 00:18:40, Interval: 00:08
# Ep. 147, Timesteps 1600, Score.Agents: 161.85, Avg.Score: 90.87, Time: 00:18:48, Interval: 00:08
# Ep. 148, Timesteps 1600, Score.Agents: 146.62, Avg.Score: 92.36, Time: 00:18:57, Interval: 00:09
# Ep. 149, Timesteps 1600, Score.Agents: 155.39, Avg.Score: 94.22, Time: 00:19:06, Interval: 00:09
# Saving model, i_episode:  150
#
# Ep. 150, Timesteps 1600, Score.Agents: 146.48, Avg.Score: 96.06, Time: 00:19:16, Interval: 00:10
# Ep. 151, Timesteps 1600, Score.Agents: 139.06, Avg.Score: 97.59, Time: 00:19:25, Interval: 00:09
# Ep. 152, Timesteps 1600, Score.Agents: 139.45, Avg.Score: 99.23, Time: 00:19:34, Interval: 00:09
# Ep. 153, Timesteps 1600, Score.Agents: 134.96, Avg.Score: 100.53, Time: 00:19:43, Interval: 00:09
# Ep. 154, Timesteps 1600, Score.Agents: 146.86, Avg.Score: 101.91, Time: 00:19:51, Interval: 00:08
# Ep. 155, Timesteps 1600, Score.Agents: 160.36, Avg.Score: 103.34, Time: 00:20:02, Interval: 00:11
# Ep. 156, Timesteps 1600, Score.Agents: 143.77, Avg.Score: 104.62, Time: 00:20:16, Interval: 00:14
# Ep. 157, Timesteps 1600, Score.Agents: 156.03, Avg.Score: 105.89, Time: 00:20:27, Interval: 00:11
# Ep. 158, Timesteps 1600, Score.Agents: 140.67, Avg.Score: 107.14, Time: 00:20:36, Interval: 00:09
# Ep. 159, Timesteps 1600, Score.Agents: 152.57, Avg.Score: 108.22, Time: 00:20:45, Interval: 00:09
# Ep. 160, Timesteps 1600, Score.Agents: 173.10, Avg.Score: 109.50, Time: 00:20:54, Interval: 00:09
# Ep. 161, Timesteps 1600, Score.Agents: 117.24, Avg.Score: 110.29, Time: 00:21:03, Interval: 00:09
# Ep. 162, Timesteps 1600, Score.Agents: 159.95, Avg.Score: 111.58, Time: 00:21:13, Interval: 00:10
# Ep. 163, Timesteps 1600, Score.Agents: 159.75, Avg.Score: 112.74, Time: 00:21:23, Interval: 00:10
# Ep. 164, Timesteps 1600, Score.Agents: 153.47, Avg.Score: 113.97, Time: 00:21:33, Interval: 00:10
# Ep. 165, Timesteps 1600, Score.Agents: 159.33, Avg.Score: 115.23, Time: 00:21:44, Interval: 00:11
# Ep. 166, Timesteps 1600, Score.Agents: 152.20, Avg.Score: 116.23, Time: 00:21:53, Interval: 00:09
# Ep. 167, Timesteps 1600, Score.Agents: 185.67, Avg.Score: 117.75, Time: 00:22:03, Interval: 00:10
# Ep. 168, Timesteps 1600, Score.Agents: 168.05, Avg.Score: 119.19, Time: 00:22:14, Interval: 00:11
# Ep. 169, Timesteps 1600, Score.Agents: 147.05, Avg.Score: 120.21, Time: 00:22:23, Interval: 00:09
# Ep. 170, Timesteps 1600, Score.Agents: 177.58, Avg.Score: 121.56, Time: 00:22:31, Interval: 00:08
# Ep. 171, Timesteps 1600, Score.Agents: 179.53, Avg.Score: 122.82, Time: 00:22:40, Interval: 00:09
# Ep. 172, Timesteps 1600, Score.Agents: 185.76, Avg.Score: 124.40, Time: 00:22:48, Interval: 00:08
# Ep. 173, Timesteps 1600, Score.Agents: 164.22, Avg.Score: 125.30, Time: 00:22:57, Interval: 00:09
# Ep. 174, Timesteps 1600, Score.Agents: 154.77, Avg.Score: 126.28, Time: 00:23:06, Interval: 00:09
# Ep. 175, Timesteps 1600, Score.Agents: 196.83, Avg.Score: 127.70, Time: 00:23:14, Interval: 00:08
# Ep. 176, Timesteps 1600, Score.Agents: 186.43, Avg.Score: 129.07, Time: 00:23:22, Interval: 00:08
# Ep. 177, Timesteps 1600, Score.Agents: 197.83, Avg.Score: 130.42, Time: 00:23:30, Interval: 00:08
# Ep. 178, Timesteps 1600, Score.Agents: 191.60, Avg.Score: 131.73, Time: 00:23:40, Interval: 00:10
# Ep. 179, Timesteps 1600, Score.Agents: 198.21, Avg.Score: 132.89, Time: 00:23:48, Interval: 00:08
# Saving model, i_episode:  180
#
# Ep. 180, Timesteps 1600, Score.Agents: 181.50, Avg.Score: 133.93, Time: 00:23:56, Interval: 00:08
# Ep. 181, Timesteps 1600, Score.Agents: 182.49, Avg.Score: 134.93, Time: 00:24:03, Interval: 00:07
# Ep. 182, Timesteps 1600, Score.Agents: 179.04, Avg.Score: 135.91, Time: 00:24:11, Interval: 00:08
# Ep. 183, Timesteps 1600, Score.Agents: 197.79, Avg.Score: 136.97, Time: 00:24:18, Interval: 00:07
# Ep. 184, Timesteps 1600, Score.Agents: 209.20, Avg.Score: 138.29, Time: 00:24:25, Interval: 00:07
# Ep. 185, Timesteps 1600, Score.Agents: 167.48, Avg.Score: 139.02, Time: 00:24:33, Interval: 00:08
# Ep. 186, Timesteps 1600, Score.Agents: 194.20, Avg.Score: 139.98, Time: 00:24:42, Interval: 00:09
# Ep. 187, Timesteps 1600, Score.Agents: 197.67, Avg.Score: 141.01, Time: 00:24:49, Interval: 00:07
# Ep. 188, Timesteps 1600, Score.Agents: 198.45, Avg.Score: 142.17, Time: 00:24:57, Interval: 00:08
# Ep. 189, Timesteps 1600, Score.Agents: 189.07, Avg.Score: 143.13, Time: 00:25:07, Interval: 00:10
# Ep. 190, Timesteps 1600, Score.Agents: 195.87, Avg.Score: 144.06, Time: 00:25:17, Interval: 00:10
# Ep. 191, Timesteps 1600, Score.Agents: 194.00, Avg.Score: 145.01, Time: 00:25:27, Interval: 00:10
# Ep. 192, Timesteps 1600, Score.Agents: 185.74, Avg.Score: 146.01, Time: 00:25:35, Interval: 00:08
# Ep. 193, Timesteps 1600, Score.Agents: 203.17, Avg.Score: 147.09, Time: 00:25:43, Interval: 00:08
# Ep. 194, Timesteps 1600, Score.Agents: 180.74, Avg.Score: 147.80, Time: 00:25:52, Interval: 00:09
# Ep. 195, Timesteps 1600, Score.Agents: 213.72, Avg.Score: 148.92, Time: 00:26:00, Interval: 00:08
# Ep. 196, Timesteps 1600, Score.Agents: 209.52, Avg.Score: 150.30, Time: 00:26:10, Interval: 00:10
# Ep. 197, Timesteps 1600, Score.Agents: 214.68, Avg.Score: 151.38, Time: 00:26:18, Interval: 00:08
# Ep. 198, Timesteps 1600, Score.Agents: 217.04, Avg.Score: 152.45, Time: 00:26:25, Interval: 00:07
# Ep. 199, Timesteps 1600, Score.Agents: 206.34, Avg.Score: 153.54, Time: 00:26:33, Interval: 00:08
# Ep. 200, Timesteps 1600, Score.Agents: 206.79, Avg.Score: 154.74, Time: 00:26:40, Interval: 00:07
# Ep. 201, Timesteps 1600, Score.Agents: 217.89, Avg.Score: 155.85, Time: 00:26:48, Interval: 00:08
# Ep. 202, Timesteps 1600, Score.Agents: 204.39, Avg.Score: 156.67, Time: 00:26:56, Interval: 00:08
# Ep. 203, Timesteps 1600, Score.Agents: 233.75, Avg.Score: 157.80, Time: 00:27:04, Interval: 00:08
# Ep. 204, Timesteps 1600, Score.Agents: 230.77, Avg.Score: 158.97, Time: 00:27:11, Interval: 00:07
# Ep. 205, Timesteps 1600, Score.Agents: 168.03, Avg.Score: 159.44, Time: 00:27:20, Interval: 00:09
# Ep. 206, Timesteps 1600, Score.Agents: 188.03, Avg.Score: 160.15, Time: 00:27:28, Interval: 00:08
# Ep. 207, Timesteps 1600, Score.Agents: 215.59, Avg.Score: 161.15, Time: 00:27:35, Interval: 00:07
# Ep. 208, Timesteps 1600, Score.Agents: 224.02, Avg.Score: 162.41, Time: 00:27:43, Interval: 00:08
# Ep. 209, Timesteps 1600, Score.Agents: 241.99, Avg.Score: 163.64, Time: 00:27:52, Interval: 00:09
# Saving model, i_episode:  210
#
# Ep. 210, Timesteps 1600, Score.Agents: 217.93, Avg.Score: 164.64, Time: 00:28:05, Interval: 00:13
# Ep. 211, Timesteps 1600, Score.Agents: 240.12, Avg.Score: 165.78, Time: 00:28:17, Interval: 00:12
# Ep. 212, Timesteps 1600, Score.Agents: 244.85, Avg.Score: 166.81, Time: 00:28:27, Interval: 00:10
# Ep. 213, Timesteps 1600, Score.Agents: 236.31, Avg.Score: 167.87, Time: 00:28:38, Interval: 00:11
# Ep. 214, Timesteps 1600, Score.Agents: 232.80, Avg.Score: 168.92, Time: 00:28:50, Interval: 00:12
# Ep. 215, Timesteps 1600, Score.Agents: 224.23, Avg.Score: 169.80, Time: 00:29:03, Interval: 00:13
# Ep. 216, Timesteps 1600, Score.Agents: 238.06, Avg.Score: 171.08, Time: 00:29:15, Interval: 00:12
# Ep. 217, Timesteps 1600, Score.Agents: 241.64, Avg.Score: 172.17, Time: 00:29:27, Interval: 00:12
# Ep. 218, Timesteps 1600, Score.Agents: 232.22, Avg.Score: 173.53, Time: 00:29:40, Interval: 00:13
# Ep. 219, Timesteps 1600, Score.Agents: 263.19, Avg.Score: 174.90, Time: 00:29:52, Interval: 00:12
# Ep. 220, Timesteps 1600, Score.Agents: 249.96, Avg.Score: 176.29, Time: 00:30:04, Interval: 00:12
# Ep. 221, Timesteps 1600, Score.Agents: 251.25, Avg.Score: 177.62, Time: 00:30:15, Interval: 00:11
# Ep. 222, Timesteps 1600, Score.Agents: 251.71, Avg.Score: 178.88, Time: 00:30:27, Interval: 00:12
# Ep. 223, Timesteps 1600, Score.Agents: 246.94, Avg.Score: 180.07, Time: 00:30:39, Interval: 00:12
# Ep. 224, Timesteps 1600, Score.Agents: 224.85, Avg.Score: 180.86, Time: 00:30:48, Interval: 00:09
# Ep. 225, Timesteps 1600, Score.Agents: 245.30, Avg.Score: 181.98, Time: 00:30:57, Interval: 00:09
# Ep. 226, Timesteps 1600, Score.Agents: 258.36, Avg.Score: 183.37, Time: 00:31:08, Interval: 00:11
# Ep. 227, Timesteps 1600, Score.Agents: 264.62, Avg.Score: 184.56, Time: 00:31:19, Interval: 00:11
# Ep. 228, Timesteps 1600, Score.Agents: 259.66, Avg.Score: 185.60, Time: 00:31:31, Interval: 00:12
# Ep. 229, Timesteps 1600, Score.Agents: 271.58, Avg.Score: 186.90, Time: 00:31:42, Interval: 00:11
# Ep. 230, Timesteps 1600, Score.Agents: 264.77, Avg.Score: 188.00, Time: 00:31:53, Interval: 00:11
# Ep. 231, Timesteps 1600, Score.Agents: 252.06, Avg.Score: 189.08, Time: 00:32:05, Interval: 00:12
# Ep. 232, Timesteps 1600, Score.Agents: 211.08, Avg.Score: 189.68, Time: 00:32:15, Interval: 00:10
# Ep. 233, Timesteps 1600, Score.Agents: 264.99, Avg.Score: 190.96, Time: 00:32:24, Interval: 00:09
# Ep. 234, Timesteps 1600, Score.Agents: 224.26, Avg.Score: 191.77, Time: 00:32:33, Interval: 00:09
# Ep. 235, Timesteps 1600, Score.Agents: 249.26, Avg.Score: 192.72, Time: 00:32:40, Interval: 00:07
# Ep. 236, Timesteps 1600, Score.Agents: 229.00, Avg.Score: 193.45, Time: 00:32:47, Interval: 00:07
# Ep. 237, Timesteps 1600, Score.Agents: 261.88, Avg.Score: 194.64, Time: 00:32:55, Interval: 00:08
# Ep. 238, Timesteps 1600, Score.Agents: 236.55, Avg.Score: 195.56, Time: 00:33:02, Interval: 00:07
# Ep. 239, Timesteps 1600, Score.Agents: 276.14, Avg.Score: 196.84, Time: 00:33:10, Interval: 00:08
# Saving model, i_episode:  240
#
# Ep. 240, Timesteps 1600, Score.Agents: 257.50, Avg.Score: 197.82, Time: 00:33:17, Interval: 00:07
# Ep. 241, Timesteps 1600, Score.Agents: 275.54, Avg.Score: 199.49, Time: 00:33:24, Interval: 00:07
# Ep. 242, Timesteps 1600, Score.Agents: 272.54, Avg.Score: 200.91, Time: 00:33:32, Interval: 00:08
# Ep. 243, Timesteps 1600, Score.Agents: 269.09, Avg.Score: 202.15, Time: 00:33:39, Interval: 00:07
# Ep. 244, Timesteps 1600, Score.Agents: 274.17, Avg.Score: 203.48, Time: 00:33:47, Interval: 00:08
# Ep. 245, Timesteps 1600, Score.Agents: 264.78, Avg.Score: 204.94, Time: 00:33:54, Interval: 00:07
# Ep. 246, Timesteps 1600, Score.Agents: 260.89, Avg.Score: 206.22, Time: 00:34:03, Interval: 00:09
# Ep. 247, Timesteps 1600, Score.Agents: 277.41, Avg.Score: 207.37, Time: 00:34:10, Interval: 00:07
# Ep. 248, Timesteps 1600, Score.Agents: 264.57, Avg.Score: 208.55, Time: 00:34:19, Interval: 00:09
# Ep. 249, Timesteps 1600, Score.Agents: 271.38, Avg.Score: 209.71, Time: 00:34:26, Interval: 00:07
# Ep. 250, Timesteps 1600, Score.Agents: 235.81, Avg.Score: 210.61, Time: 00:34:33, Interval: 00:07
# Ep. 251, Timesteps 1600, Score.Agents: 273.63, Avg.Score: 211.95, Time: 00:34:41, Interval: 00:08
# Ep. 252, Timesteps 1600, Score.Agents: 283.93, Avg.Score: 213.40, Time: 00:34:48, Interval: 00:07
# Ep. 253, Timesteps 1600, Score.Agents: 284.79, Avg.Score: 214.89, Time: 00:34:56, Interval: 00:08
# Ep. 254, Timesteps 1600, Score.Agents: 274.74, Avg.Score: 216.17, Time: 00:35:03, Interval: 00:07
# Ep. 255, Timesteps 1600, Score.Agents: 285.61, Avg.Score: 217.43, Time: 00:35:10, Interval: 00:07
# Ep. 256, Timesteps 1600, Score.Agents: 276.91, Avg.Score: 218.76, Time: 00:35:18, Interval: 00:08
# Ep. 257, Timesteps 1600, Score.Agents: 282.58, Avg.Score: 220.02, Time: 00:35:25, Interval: 00:07
# Ep. 258, Timesteps 1600, Score.Agents: 286.97, Avg.Score: 221.49, Time: 00:35:34, Interval: 00:09
# Ep. 259, Timesteps 1600, Score.Agents: 268.61, Avg.Score: 222.65, Time: 00:35:41, Interval: 00:07
# Ep. 260, Timesteps 1600, Score.Agents: 277.57, Avg.Score: 223.69, Time: 00:35:48, Interval: 00:07
# Ep. 261, Timesteps 1600, Score.Agents: 289.01, Avg.Score: 225.41, Time: 00:35:57, Interval: 00:09
# Ep. 262, Timesteps 1600, Score.Agents: 258.53, Avg.Score: 226.39, Time: 00:36:06, Interval: 00:09
# Ep. 263, Timesteps 1600, Score.Agents: 277.04, Avg.Score: 227.57, Time: 00:36:14, Interval: 00:08
# Ep. 264, Timesteps 1600, Score.Agents: 283.05, Avg.Score: 228.86, Time: 00:36:22, Interval: 00:08
# Ep. 265, Timesteps 1600, Score.Agents: 278.10, Avg.Score: 230.05, Time: 00:36:34, Interval: 00:12
# Ep. 266, Timesteps 1600, Score.Agents: 295.77, Avg.Score: 231.49, Time: 00:36:44, Interval: 00:10
# Ep. 267, Timesteps 1600, Score.Agents: 277.11, Avg.Score: 232.40, Time: 00:36:56, Interval: 00:12
# Ep. 268, Timesteps 1600, Score.Agents: 288.49, Avg.Score: 233.60, Time: 00:37:08, Interval: 00:12
# Ep. 269, Timesteps 1600, Score.Agents: 300.71, Avg.Score: 235.14, Time: 00:37:21, Interval: 00:13
# Saving model, i_episode:  270
#
# Ep. 270, Timesteps 1600, Score.Agents: 268.37, Avg.Score: 236.05, Time: 00:37:32, Interval: 00:11
# Ep. 271, Timesteps 1600, Score.Agents: 275.86, Avg.Score: 237.01, Time: 00:37:42, Interval: 00:10
# Ep. 272, Timesteps 1600, Score.Agents: 309.51, Avg.Score: 238.25, Time: 00:37:52, Interval: 00:10
# Ep. 273, Timesteps 1600, Score.Agents: 299.79, Avg.Score: 239.61, Time: 00:38:01, Interval: 00:09
# Ep. 274, Timesteps 1600, Score.Agents: 288.30, Avg.Score: 240.94, Time: 00:38:11, Interval: 00:10
# Ep. 275, Timesteps 1600, Score.Agents: 269.17, Avg.Score: 241.66, Time: 00:38:23, Interval: 00:12
# Ep. 276, Timesteps 1600, Score.Agents: 284.91, Avg.Score: 242.65, Time: 00:38:34, Interval: 00:11
# Ep. 277, Timesteps 1600, Score.Agents: 297.12, Avg.Score: 243.64, Time: 00:38:43, Interval: 00:09
# Ep. 278, Timesteps 1600, Score.Agents: 292.03, Avg.Score: 244.65, Time: 00:38:52, Interval: 00:09
# Ep. 279, Timesteps 1600, Score.Agents: 297.48, Avg.Score: 245.64, Time: 00:39:01, Interval: 00:09
# Ep. 280, Timesteps 1600, Score.Agents: 298.10, Avg.Score: 246.80, Time: 00:39:10, Interval: 00:09
# Ep. 281, Timesteps 1600, Score.Agents: 301.16, Avg.Score: 247.99, Time: 00:39:18, Interval: 00:08
# Ep. 282, Timesteps 1600, Score.Agents: 292.98, Avg.Score: 249.13, Time: 00:39:25, Interval: 00:07
# Ep. 283, Timesteps 1600, Score.Agents: 289.57, Avg.Score: 250.05, Time: 00:39:32, Interval: 00:07
# Environment solved with Average Score:  250.04898717466057

# %%
save(model=policy,directory='dir_save',filename='we0',suffix='final')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print('length of scores: ', len(scores), ', len of avg_scores: ', len(avg_scores))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label="Score")
plt.plot(np.arange(1, len(avg_scores)+1), avg_scores, label="Avg on 100 episodes")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.show()
# Out:
# length of scores:  284 , len of avg_scores:  284

# %%
#--------------- make_vec_envs ----------------
## we continue with the same model, model Policy uses MLPBase, but with new environment env_venv

device = torch.device("cpu")
print('device: ', device)

seed = 0 
num_processes=1  

env_venv = make_vec_envs('BipedalWalker-v2', \
                    seed + 1000, num_processes,
                    None, None, False, device='cpu', allow_early_resets=False)

policy = policy.to(device)

print('env_venv.observation_space.shape: ', env_venv.observation_space.shape, \
      ', len(obs_shape): ', len(env_venv.observation_space.shape))
print('env_venv.action_space: ',  env_venv.action_space, \
      ', action_space.shape[0]: ', env_venv.action_space.shape[0])
# Out:
# device:  cpu
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# env_venv.observation_space.shape:  (24,) , len(obs_shape):  1
# env_venv.action_space:  Box(4,) , action_space.shape[0]:  4
# d:\Python\Python37\lib\site-packages\gym\envs\registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
## No CUDA, only CPU

def play_VecEnv(env, model, num_episodes):

    obs = env.reset()
    obs = torch.Tensor(obs)
    obs = obs.float()
        
    recurrent_hidden_states = torch.zeros(1, model.recurrent_hidden_state_size)
    
    masks = torch.zeros(1, 1)
    
    scores_deque = deque(maxlen=100)

    render_func = get_render_func(env)
        
    for i_episode in range(1, num_episodes+1):     

        time_start = time.time()
        total_reward = np.zeros(num_processes)
        timestep = 0

        while True:
        
            with torch.no_grad():
                value, action, _, recurrent_hidden_states = \
                    model.act(obs, recurrent_hidden_states, masks, \
                    deterministic=False) # obs = state

            render_func()
            
            obs, reward, done, _ = env.step(action)
            obs = torch.Tensor(obs)
            obs = obs.float()

            reward = reward.detach().numpy()
            
            masks.fill_(0.0 if done else 1.0)
            
            total_reward += reward[0]
        
            #if timestep < 800:
            #    print('timestep: ', timestep, 'reward: ', reward[0])
            
            timestep += 1
            
            if timestep + 1 == 1600: ##   envs.max_steps:
                break

        s = (int)(time.time() - time_start)
        
        scores_deque.append(total_reward[0])
        
        avg_score = np.mean(scores_deque)
                    
        print('Episode {} \tScore: {:.2f}, Avg.Score: {:.2f}, \tTime: {:02}:{:02}:{:02}'\
                  .format(i_episode, total_reward[0], avg_score,  s//3600, s%3600//60, s%60))

# %%
play_VecEnv(env=env_venv, model=policy, num_episodes=5)
# Out:
# Episode 1 	Score: 327.09, Avg.Score: 327.09, 	Time: 00:00:29
# Episode 2 	Score: 324.11, Avg.Score: 325.60, 	Time: 00:00:27
# Episode 3 	Score: 319.85, Avg.Score: 323.68, 	Time: 00:00:28
# Episode 4 	Score: 326.20, Avg.Score: 324.31, 	Time: 00:00:28
# Episode 5 	Score: 345.76, Avg.Score: 328.60, 	Time: 00:00:28

# %%
env_venv.close()
obs = env_venv.reset()
#obs.close()
env_venv.close()

# %%
#def load(model):
#    model.base.actor.load_state_dict(torch.load('dir_save_VecEnv\we0_actor_final.pth'))
#    model.base.critic.load_state_dict(torch.load('dir_save_VecEnv\we0_critic_final.pth'))
#    model.base.critic_linear.load_state_dict(torch.load('dir_save_VecEnv\we0_critic_linear_final.pth'))

#def load_venv(model):
#    model.base, ob_rms = \
#            torch.load('dir_save_VecEnv\weights_venv_final.pth')


# load(model=policy)    
# load_venv(model=policy)
# play_episode_parallelEnv(envs=envs, model=policy)
